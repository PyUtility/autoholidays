# %%
import os
import sys

# %%
sys.path.append(os.path.join(".."))

# %%
import autoholidays as ah

# %%
ah.PersonConstruct(name = "John Doe", holidays = [], creditDays = [], requiredLeaves = [])
# Out:
# PersonConstruct(name='John Doe', holidays=[], creditDays=[], requiredLeaves=[], opening=0, weekoff=[<ENUMDays.SATURDAY: 5>, <ENUMDays.SUNDAY: 6>])
